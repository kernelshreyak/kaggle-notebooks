# %% [markdown]
# ## House rent prediction model
#
# **Problem statement**: Given the location of a house and it's related details, predict the rent

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exploratory analysis

# %%
data = pd.read_csv("/kaggle/input/house-rent-prices-of-metropolitan-cities-in-india/Delhi_rent.csv")
data.sort_values('price',ascending=False).head()
# Out:
#       seller_type  bedroom layout_type      property_type         locality  \
# 77          OWNER      4.0         BHK  Independent Floor    Malviya Nagar
# 25735       AGENT      3.0         BHK          Apartment  Greater Kailash
# 32108       OWNER      3.0         BHK          Apartment    Malviya Nagar
# 12226       AGENT      4.0         BHK  Independent Floor        Pitampura
# 27912       OWNER      5.0         BHK  Independent Floor          Kalkaji
#
#         price    area    furnish_type     bathroom
# 77     99,000  3000.0  Semi-Furnished  4 bathrooms
# 25735  98,000  2116.0       Furnished  3 bathrooms
# 32108  98,000  1800.0       Furnished  3 bathrooms
# 12226  98,000  3200.0  Semi-Furnished  4 bathrooms
# 27912  98,000  2700.0       Furnished  5 bathrooms

# %%
data.query('area > 2000')
# Out:
#       seller_type  bedroom layout_type      property_type            locality  \
# 25          AGENT      3.0         BHK          Apartment        Vasant Vihar
# 41          AGENT      3.0         BHK  Independent Floor          Neeti Bagh
# 46          AGENT      3.0         BHK  Independent Floor     Panchsheel Park
# 47          AGENT      2.0         BHK  Independent Floor      Defence Colony
# 77          OWNER      4.0         BHK  Independent Floor       Malviya Nagar
# ...           ...      ...         ...                ...                 ...
# 33403       OWNER      3.0         BHK  Independent Floor         Preet Vihar
# 33431       OWNER      2.0         BHK  Independent Floor     Sector-7 Rohini
# 33433       OWNER      4.0         BHK          Penthouse    Sector 11 Dwarka
# 33439       OWNER      3.0         BHK  Independent Floor         Ashok Vihar
# 33480       OWNER      4.0         BHK  Independent Floor  New Friends Colony
#
# ...

# %%
data.plot.scatter(x='bedroom',y='area')
# Out:
# <AxesSubplot:xlabel='bedroom', ylabel='area'>
